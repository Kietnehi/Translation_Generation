# %% [markdown]
# ```mermaid
# graph TD
#     A[User Input Text] --> B{Frontend Web UI}
#     B -- Configured System Prompt --> C[System Prompt Designer]
#     C --> D[Logic Splitting Engine]
#     D -- Separate Instructions for each Target Lang --> E[FastAPI Backend]
#     E -- Load Model (HY-MT1.5-1.8B) --> F[Inference Engine (4-bit Quantized)]
#     F -- Parallel Translation --> G{Translated Output per Language}
#     G --> B
#     B -- Display Results --> H[User Interface]
#
#     style B fill:#f9f,stroke:#333,stroke-width:2px
#     style C fill:#f9f,stroke:#333,stroke-width:2px
#     style E fill:#00d1b2,stroke:#333,stroke-width:2px
#     style F fill:#00d1b2,stroke:#333,stroke-width:2px
#     style H fill:#3273dc,stroke:#fff,stroke-width:4px
# ```
